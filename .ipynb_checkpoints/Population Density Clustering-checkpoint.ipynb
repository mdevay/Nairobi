# %% [markdown]
# # Clustering - Population Density

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# %%
pop_df = pd.read_csv('./datasets/Nairobi_Area_Population_Grid.csv')
pop_df.head(3)
# Out:
#    Unnamed: 0       Lat        Lon  Population
# 0     9429455 -1.050139  36.698194     4.18689
# 1     9429456 -1.050139  36.699306     4.18689
# 2     9429457 -1.050139  36.699583     4.18689

# %% [markdown]
# ---
# ### Model

# %%
def best_model(pop_df, pop_min):
    X = pop_df[pop_df['Population'] > pop_min].copy()
    #X.drop(columns = 'Population', inplace = True)
    scores = []
    for k in range(25, 30):
        cl = KMeans(n_clusters=k)
        cl.fit(X)
        X['clusters'] = cl.labels_
        X = X.sample(20_000, random_state=510)
        sil = silhouette_score(X.drop(columns='clusters'), X.clusters)
        scores.append([k, sil])

    score_df = pd.DataFrame(scores)
    score_df.columns = ['k', 'silhouette']
    return score_df

# %%
def best_sil(score_df):
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(score_df.k, score_df.silhouette);
    ax.set_title('Silhouette Score over k')

# %% [markdown]
# #### Population > 4
#
# > results: k = 25, silhouette = 0.42

# %%
score_df = best_model(pop_df, 4)
print(score_df.sort_values('silhouette', ascending = False).head(1))
# Out:
#     k  silhouette
# 3  28    0.538542

# %% [markdown]
# #### Population > 6
#
# >results: k = 26, silhouette = 0.44

# %%
score_df = best_model(pop_df, 6)
print(score_df.sort_values('silhouette', ascending=False).head(1))
# Out:
#     k  silhouette
# 2  27    0.538186

# %% [markdown]
# #### Population > 7
#
# > results: k = 25, silouette = 0.45

# %%
score_df = best_model(pop_df, 7)
print(score_df.sort_values('silhouette', ascending=False).head(1))
# Out:
#     k  silhouette
# 1  26    0.539785

# %% [markdown]
# #### Population > 8
#
# >results: k = 28, silhouette = 0.46

# %%
score_df = best_model(pop_df, 8)
print(score_df.sort_values('silhouette', ascending=False).head(1))
# Out:
#     k  silhouette
# 2  27    0.537267

# %% [markdown]
# #### Population > 2
#
# >results: k = 25, silhouette = 0.40

# %%
score_df = best_model(pop_df, 2)
print(score_df.sort_values('silhouette', ascending=False).head(1))
# Out:
#     k  silhouette
# 2  27    0.535049

# %%
pop_df[pop_df['Population'] > 2].shape[0] / pop_df.shape[0]
# Out:
# 0.9324834119396775

# %% [markdown]
# ---
# ### DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
def best_DBSCAN(pop_df, pop_min):
    '''
    Creates a DBSCAN model taking population dataframe, filters based on population size,
    and returns silhouette score.
    '''
    # filter by population size
    X = pop_df[pop_df['Population'] > pop_min].copy()
    X.drop(columns = 'Population', inplace = True)
    
    # create and fit DBSCAN model
    dbscan = DBSCAN()
    dbscan.fit(X)
    
    # add cluster labels back to dataframe
    X['clusters'] = dbscan.labels_
    X = X.sample(20_000, random_state=510)
    
    # return silhouette score
    sil = silhouette_score(X.drop(columns = ['clusters']), X.clusters)
    return sil

# %%
score = best_DBSCAN(pop_df, 4)
score

# %% [markdown]
# ---

# %%
# scores = []
# for k in range(25, 40):
#     cl = KMeans(n_clusters=k)
#     cl.fit(X)
#     X['clusters'] = cl.labels_
#     X = X.sample(20_000, random_state=510)
#     sil = silhouette_score(X.drop(columns='clusters'), X.clusters)
#     scores.append([k, sil])
    
# score_df = pd.DataFrame(scores)
# score_df.columns = ['k', 'silhouette']

# %%
# fig, ax = plt.subplots(figsize=(14, 7))
# ax.plot(score_df.k, score_df.silhouette);
# ax.set_title('Silhouette Score over k')

# %%
import numpy as np

# X features from Latitude and Longitude
pop = pop_df[pop_df['Population'] > 4].copy()
X = pop[['Lat', 'Lon', 'Population']]
ss = StandardScaler()
X = ss.fit_transform(X)
#X.drop(columns = 'Population', inplace = True)

# fit kmeans model
km = KMeans(n_clusters=28, random_state=510)
km.fit(X)

pop['clusters'] = km.labels_
centroids = pop.groupby('clusters')[['Lat', 'Lon']].mean()

# %%
#Plot scatter by cluster / color, and centroids
#colors = np.random.rand(28,)
#X['color'] = X['clusters'].map(lambda p: colors[p])

ax = pop.plot(    
    kind="scatter", 
    x='Lat', y='Lon',
    figsize=(10,8),
    c = km.labels_.astype(float)
)

centroids.plot(
    kind="scatter", 
    x="Lat", y="Lon", 
    marker="*"#, c=km.labels_.astype(float)
);

# %% [markdown]
# ---

# %% [markdown]
# ### Results

# %%
# pop_gt_4.groupby('clusters')[['Lat', 'Lon']].mean()

# %%
# pop_gt_4.groupby('clusters')['Population'].mean().sort_values(ascending=False)

# %%
pop.to_csv('./datasets/Nairobi_Area_Population_Clusters.csv')
