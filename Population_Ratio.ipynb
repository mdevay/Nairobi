# %% [markdown]
# # Population Ratio per Cluster

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
with open('cluster_model.pkl', 'rb') as model_in:
    km = pickle.load(model_in)

# %%
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=27, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=510, tol=0.0001, verbose=0)

# %%
df_adverts = pd.read_csv('adverts_geocoded.csv')
df_adverts.head(3)
# Out:
#    Unnamed: 0       id          category list_type  beds  baths  sq_ft_price  \
# 0           0  3394167  Flat & Apartment  For Rent     2      0            0
# 1           1  3399035  Flat & Apartment  For Rent     2      0           77
# 2           2  3433894  Flat & Apartment  For Rent     2      0           46
#
#    price_KES         district   neighborhood     street  latitude  longitude  \
# 0     120000        Westlands      Brookside          0 -1.256163  36.791940
# 1      96000        Ridgeways              0          0 -1.230687  36.849247
# 2      70000  Dagoretti North  Valley Arcade  Lavington -1.290723  36.769157
#
#   clean_grab
# 0         OK
# 1         OK
# 2         OK

# %%
advert_locs = df_adverts.loc[:,['latitude', 'longitude']]
advert_locs.head()
# Out:
#    latitude  longitude
# 0 -1.256163  36.791940
# 1 -1.230687  36.849247
# 2 -1.290723  36.769157
# 3 -1.258453  36.804754
# 4 -1.263270  36.815948

# %%
advert_locs.shape
# Out:
# (4000, 2)

# %%
advert_locs.dtypes
# Out:
# latitude     float64
# longitude    float64
# dtype: object

# %%
advert_locs.describe()
# Out:
#           latitude    longitude
# count  4000.000000  4000.000000
# mean     -1.264698    36.693415
# std       0.604558     2.909096
# min      -1.430525  -119.417932
# 25%      -1.294270    36.781686
# 50%      -1.279206    36.799370
# 75%      -1.265717    36.803513
# max      36.778261    36.963968

# %%
extreme = df_adverts['latitude'] >= 0
df_adverts.loc[extreme, :]
# Out:
#       Unnamed: 0       id          category list_type  beds  baths  \
# 54            54  3433417            Studio  For Rent     1      1
# 156          156  3430967  Flat & Apartment  For Rent     4      0
# 258          258  3426717  Flat & Apartment  For Rent     3      4
# 1838        1838  3421610            Studio  For Rent     1      0
# 1881        1881  3433862  Flat & Apartment  For Rent     4      2
# 1947        1947  3429200  Flat & Apartment  For Rent     3      3
# 3190        3190  3432233  Flat & Apartment  For Sale     2      0
# 3304        3304  3429197  Flat & Apartment  For Sale     4      4
#
#       sq_ft_price  price_KES                district   neighborhood  \
# 54              0     100000         Dagoretti North       Kilimani
# 156            54     135000         Dagoretti North       Kilimani
# 258             0      90000         Dagoretti North       Kilimani
# 1838            0      40000         Dagoretti North       Kilimani
# 1881            0      75000         Dagoretti North       Kilimani
# 1947            0      75000         Dagoretti North  Valley Arcade
# 3190            0   26000000  Kamukunji Constituency      Eastleigh
# 3304         8029   21000000         Dagoretti North      Lavington
#
#                               street   latitude   longitude    clean_grab
# 54                            Tigoni   0.000000    0.000000  ZERO_RESULTS
# 156                          Nairobi   0.000000    0.000000  ZERO_RESULTS
# 258                          Nairobi   0.000000    0.000000  ZERO_RESULTS
# 1838                       Ring Road   0.000000    0.000000  ZERO_RESULTS
# 1881                    Walk To Yaya   0.000000    0.000000  ZERO_RESULTS
# 1947  Walk To Valley Arcade Shopping   0.000000    0.000000  ZERO_RESULTS
# 3190                      California  36.778261 -119.417932            OK
# 3304           Walk To Valley Arcade   0.000000    0.000000  ZERO_RESULTS

# %%
# drop outliers
advert_locs.drop(index = (df_adverts.loc[extreme, :].index), inplace = True)

advert_locs.describe()
# Out:
#           latitude    longitude
# count  3992.000000  3992.000000
# mean     -1.276445    36.796863
# std       0.025429     0.033817
# min      -1.430525    36.603554
# 25%      -1.294270    36.781686
# 50%      -1.279513    36.799370
# 75%      -1.265717    36.803513
# max      -1.130738    36.963968

# %%
ss = StandardScaler()
advert_locs = ss.fit_transform(advert_locs)

# %%
advert_locs
# Out:
# array([[ 0.79767287, -0.14558427],
#        [ 1.79963681,  1.54923592],
#        [-0.56155044, -0.81938729],
#        ...,
#        [-0.43013412, -0.53743826],
#        [-2.30262994, -3.67439659],
#        [-0.70104509,  0.07414285]])

# %%
advert_locs = pd.DataFrame(advert_locs, columns = ['latitude', 'longitude'])

# %%
# assign cluster labels to advert data
advert_locs['cluster'] = km.predict(advert_locs)

# %%
len(advert_locs['cluster'].unique())
# Out:
# 27

# %%
adverts = []
for i in range(26):
    adverts.append(advert_locs.groupby('cluster').count().loc[i][0])

# %%
pop = pd.read_csv('./datasets/Nairobi_Area_Population_Clusters.csv')
pop.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       Lat        Lon  Population  clusters
# 0           0       9429455 -1.050139  36.698194     4.18689        22
# 1           1       9429456 -1.050139  36.699306     4.18689        22
# 2           2       9429457 -1.050139  36.699583     4.18689        22
# 3           3       9429458 -1.050139  36.701250     4.18689        22
# 4           4       9429459 -1.050139  36.702639     4.18689        22

# %%
advert_pop_ratio = []
for i in range(26):
    advert_pop_ratio.append(adverts[i] / pop.groupby('clusters')['Population'].mean()[i])

# %%
advert_pop_ratio
# Out:
# [0.4138615600228044,
#  0.38876832172369763,
#  15.484692780414552,
#  0.1869707039525563,
#  7.013443544767667,
#  8.677806028216148,
#  13.905433374146378,
#  3.8918651695858117,
#  7.285022756596774,
#  19.072198902002317,
#  1.8933190504003379,
#  17.667609339873216,
#  7.5316742779287145,
#  0.5520075987393818,
#  4.454998177595786,
#  11.486704766442559,
#  28.080449520180938,
#  20.143562296702154,
#  2.6626519200886385,
#  0.3301990744820585,
#  2.6913768535135545,
#  6.514870455178825,
#  2.8970256699956436,
#  10.304434522855544,
#  38.010932151911206,
#  4.089884204236117]

# %%
advert_pop_ratio = [0] + advert_pop_ratio

# %%
pop['advert ratio'] = pop['clusters'].map(lambda x: advert_pop_ratio[x])

# %%
pop
# Out:
#         Unnamed: 0  Unnamed: 0.1       Lat        Lon  Population  clusters  \
# 0                0       9429455 -1.050139  36.698194     4.18689        22
# 1                1       9429456 -1.050139  36.699306     4.18689        22
# 2                2       9429457 -1.050139  36.699583     4.18689        22
# 3                3       9429458 -1.050139  36.701250     4.18689        22
# 4                4       9429459 -1.050139  36.702639     4.18689        22
# ...            ...           ...       ...        ...         ...       ...
# 238612      322062      10287703 -1.499861  36.968750     4.25467         4
# 238613      322063      10287704 -1.499861  36.969028     4.25467         4
# 238614      322064      10287705 -1.499861  36.969306     4.25467         4
# 238615      322065      10287706 -1.499861  36.969583     4.25467         4
# 238616      322066      10287707 -1.499861  36.987639    10.16805         4
#
#         advert ratio
# 0           6.514870
# 1           6.514870
# 2           6.514870
# 3           6.514870
# 4           6.514870
# ...              ...
# 238612      0.186971
# 238613      0.186971
# 238614      0.186971
# 238615      0.186971
# 238616      0.186971
#
# [238617 rows x 7 columns]

# %%
pop.groupby('clusters')['advert ratio'].mean().sort_values(ascending=False).to_frame()
# Out:
#           advert ratio
# clusters
# 25           38.010932
# 17           28.080450
# 18           20.143562
# 10           19.072199
# 12           17.667609
# 3            15.484693
# 7            13.905433
# 16           11.486705
# 24           10.304435
# 6             8.677806
# 13            7.531674
# 9             7.285023
# 5             7.013444
# 22            6.514870
# 15            4.454998
# 26            4.089884
# 8             3.891865
# 23            2.897026
# 21            2.691377
# 19            2.662652
# 11            1.893319
# 14            0.552008
# 1             0.413862
# 2             0.388768
# 20            0.330199
# 4             0.186971
# 0             0.000000

# %%
pop.to_csv('./datasets/Nairobi_Advert_Ratios.csv')
